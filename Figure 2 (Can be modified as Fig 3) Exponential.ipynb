# %%
#Here, we define 
import numpy as np
import math
import matplotlib.pyplot as plt
from sympy import *
import sympy
from sklearn.linear_model import LinearRegression
from sympy import re, im, I, E, symbols, exp
from sklearn.model_selection import train_test_split
from scipy.optimize import minimize
import time

import tensorflow as tf

import glob
from tensorflow.keras.layers import Dense,Flatten,Cropping1D, Concatenate, MaxPooling1D, Dropout, Reshape, Conv1D, BatchNormalization, Activation, AveragePooling1D, GlobalAveragePooling1D, Lambda, Input, Concatenate, Add, UpSampling1D, Multiply
from tensorflow.keras.models import Model
from tensorflow.keras import losses
from tensorflow.keras.losses import Hinge
from tensorflow.keras import backend as K
from tensorflow.keras.losses import binary_crossentropy, categorical_crossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau,LearningRateScheduler
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.models import Sequential
from sklearn.metrics import cohen_kappa_score, f1_score
from sklearn.model_selection import KFold, train_test_split

from scipy.special import legendre
from scipy.special import chebyt, chebyu



import numpy as np
from scipy.special import pro_ang1
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Definimos el valor de K

def Archit(K):

# We create an arrange with K values
    Array = np.arange(1, K[0] + 1)

# e create an arrange of the form (j, K * j)
    Lay_x_Neu = np.column_stack((Array, K[1] * Array))

    return Lay_x_Neu

# %%
#Number of samples and parameters

max_order_slep = 35 # increase to 20 or more eventually

Nsamples = np.logspace(1, np.log10(10000), 10).astype(int)
Ntest= 1000

#Para_slep = np.linspace(1, max_order_slep+1, 10).astype(int)
Para_slep= [10]
total_runs = 20

# %%
Nsamples
# Out:
# array([   10,    21,    46,   100,   215,   464,  1000,  2154,  4641,
#        10000])

# %%
# Define the samples 
def samps(t):
       
    Values = np.random.uniform(-1, 1, int(t[0]) if isinstance(t, (list, np.ndarray)) else int(t))

    
    #Ordenar os valores de mayor a menor
    #OValues = np.sort(Values)  # [::-1] invierte el orden
    
    return Values

# %%
#This is the function that we approximate
def funct(x):
    # t is the variable
    g = np.exp(-0.5*x**2)

    
    return g

# %%
#Compute the cheby with j and c at the value x.

def Cheby(x, j):
    
    norm = np.sqrt(np.pi) if j == 0 else np.sqrt(np.pi / 2)
    return chebyt(j)(x) / norm

# %%
#We know create the matrix for the ls approximation

def MatrixC(samp, ordens):

    A= np.zeros((len(samp), ordens))
    #We create the matrix for the least square
    for j in range(ordens):
        for k in range(len(samp)):
            A[k,j]= Cheby(samp[k], j)
    
    return A

# %%
#Compute the PSWF with j and c at the value x.

def Legend(x, j):
    
    leg=legendre(j)(x)
    
    l2_norm = np.sqrt(2 / (2 * j + 1))
    
    return leg/l2_norm

# %%
#We know create the matrix for the ls approximation

def MatrixL(samp, ordens):

    A= np.zeros((len(samp), ordens))
    #We create the matrix for the least square
    for j in range(ordens):
        for k in range(len(samp)):
            A[k,j]= Legend(samp[k], j)
    
    return A

# %%
#Returns the Slepian basis function

def NorSlep(j, c):
    b = 0 # Alpha parameter for the PSAF
    theta = np.linspace(-1, 1, 200)
    
    psaf_values = pro_ang1(b, j, c, theta)
    psaf_values = psaf_values[0] 
    
    psaf_values = psaf_values[1:199]
    l2_norm = np.linalg.norm(psaf_values)/np.sqrt(len(theta)-1)
    
    
    return l2_norm

norms_ = np.zeros([Para_slep[-1]])
for k in range(Para_slep[-1]):
    norms_[k] = NorSlep(k, 4)

# %%
#Compute the PSWF with j and c at the value x.

def PSWF(x, j, c):
    
    b = 0 # Alpha parameter for the PSAF
    
    # Calculate the PSAF values for the two modes
    psaf_values = pro_ang1(b, j, c, x)
    psaf_values = psaf_values[0] 
    
    
  
    l2_norm = norms_[j]
    
    return psaf_values/l2_norm

# %%
#We know create the matrix for the ls approximation

def Matrix(samp, ordens):

    A= np.zeros((len(samp), ordens))
    #We create the matrix for the least square
    for j in range(ordens):
        for k in range(len(samp)):
            A[k,j]= PSWF(samp[k], j, 4)
    
    return A

# %%
# Initialize the error vector
MSE_cheby = np.zeros([len(Para_slep), len(Nsamples), total_runs])
MSE_leg = np.zeros([len(Para_slep), len(Nsamples), total_runs])
MSE_slep = np.zeros([len(Para_slep), len(Nsamples), total_runs])

start_time = time.time()
total_iterations = total_runs * len(Para_slep) * len(Nsamples)
counter = 0

# test set can be the same always

for run in range(total_runs):
    # produce the matrix first, then take rectangles. It takes too long to recreate it every time.
    SamSet_ = samps(Nsamples[-1])
    y_ = funct(SamSet_)

    A_c_ = MatrixC(SamSet_, Para_slep[-1])
    A_l_ = MatrixL(SamSet_, Para_slep[-1])
    A_ = Matrix(SamSet_, Para_slep[-1])
    
    TestSet = samps(Ntest)
    Values_test = funct(TestSet)

    test_cheby_matrix_ = np.array([[Cheby(t, i) for i in range(Para_slep[-1])] for t in TestSet]) 
    test_leg_matrix_ = np.array([[Legend(t, i) for i in range(Para_slep[-1])] for t in TestSet]) 
    test_PSWF_matrix_ = np.array([[PSWF(t, i, 4) for i in range(Para_slep[-1])] for t in TestSet])    


    for orde in range(len(Para_slep)):
        
        for k in range(len(Nsamples)):
            # Generate sample and test sets
            A_c = A_c_[:Nsamples[k], :Para_slep[orde]]
            A_l = A_l_[:Nsamples[k], :Para_slep[orde]]
            A_s = A_[:Nsamples[k], :Para_slep[orde]]
            SamSet = SamSet_[:Nsamples[k]]
            y = y_[:Nsamples[k]]
            
            test_cheby_matrix = test_cheby_matrix_[:, :Para_slep[orde]]
            test_leg_matrix = test_leg_matrix_[:, :Para_slep[orde]]
            test_PSWF_matrix = test_PSWF_matrix_[:, :Para_slep[orde]]
            
            #Values_test = funct(TestSet)

            #Now for cheby

            # Solve the linear regression problem using lstsq (least squares)
            x =  np.linalg.lstsq(A_c, y, rcond=None)[0]
            linear_combination_t = test_cheby_matrix@x             # Calculate the linear combination on the test set in a vectorized manner
            Err = np.linalg.norm(linear_combination_t - Values_test) / np.sqrt(Ntest) # Calculate the error
            MSE_cheby[orde, k, run] = Err


            #Then for legendre
            x =  np.linalg.lstsq(A_l, y, rcond=None)[0]
            linear_combination_t = test_leg_matrix@x             # Calculate the linear combination on the test set in a vectorized manner
            Err = np.linalg.norm(linear_combination_t - Values_test) / np.sqrt(Ntest) # Calculate the error
            MSE_leg[orde, k, run] = Err

            #Then for legendre
            x =  np.linalg.lstsq(A_s, y, rcond=None)[0]
            linear_combination_t = test_PSWF_matrix@x             # Calculate the linear combination on the test set in a vectorized manner
            Err = np.linalg.norm(linear_combination_t - Values_test) / np.sqrt(Ntest) # Calculate the error
            MSE_slep[orde, k, run] = Err

            counter += 1
            now_time = time.time()
            print('Error: ' + str(Err) +  ', Progress: ' + format(100*counter / total_iterations, '.2f') + '%' + ', approx. ' + format((total_iterations-counter)*(now_time -  start_time)/counter, '.1f') + ' seconds remaining.')
# Out:
# Error: 2.2514002838288267e-07, Progress: 0.50%, approx. 12673.8 seconds remaining.
# Error: 1.1342119297742095e-07, Progress: 1.00%, approx. 6305.1 seconds remaining.
# Error: 1.1686164257622609e-07, Progress: 1.50%, approx. 4182.2 seconds remaining.
# Error: 6.505348507464032e-08, Progress: 2.00%, approx. 3120.8 seconds remaining.
# Error: 1.1535775977178484e-08, Progress: 2.50%, approx. 2483.9 seconds remaining.
# Error: 1.1576800601879532e-08, Progress: 3.00%, approx. 2059.3 seconds remaining.
# Error: 1.1633040753785329e-08, Progress: 3.50%, approx. 1756.1 seconds remaining.
# Error: 1.1539782517321698e-08, Progress: 4.00%, approx. 1528.7 seconds remaining.
# Error: 1.159712523899748e-08, Progress: 4.50%, approx. 1351.8 seconds remaining.
# Error: 1.145079378034531e-08, Progress: 5.00%, approx. 1210.4 seconds remaining.
# Error: 1.6893507996560561e-07, Progress: 5.50%, approx. 2191.7 seconds remaining.
# Error: 2.744342199024683e-08, Progress: 6.00%, approx. 1998.4 seconds remaining.
# Error: 2.2032309748429906e-08, Progress: 6.50%, approx. 1834.9 seconds remaining.
# Error: 1.3420258038010704e-08, Progress: 7.00%, approx. 1694.7 seconds remaining.
# Error: 1.2680749357432347e-08, Progress: 7.50%, approx. 1573.3 seconds remaining.
# Error: 1.1692808592212067e-08, Progress: 8.00%, approx. 1467.0 seconds remaining.
# Error: 1.1692215634723466e-08, Progress: 8.50%, approx. 1373.2 seconds remaining.
# Error: 1.1629539097056355e-08, Progress: 9.00%, approx. 1289.8 seconds remaining.
# Error: 1.1564534723751688e-08, Progress: 9.50%, approx. 1215.3 seconds remaining.
# Error: 1.1599839114956383e-08, Progress: 10.00%, approx. 1148.2 seconds remaining.
# Error: 2.002683684490404e-08, Progress: 10.50%, approx. 1623.0 seconds remaining.
# Error: 4.3957456444524295e-08, Progress: 11.00%, approx. 1540.6 seconds remaining.
# Error: 2.093845425142117e-08, Progress: 11.50%, approx. 1465.3 seconds remaining.
# Error: 1.831312625009357e-08, Progress: 12.00%, approx. 1396.3 seconds remaining.
# Error: 1.1863760606779883e-08, Progress: 12.50%, approx. 1332.9 seconds remaining.
# Error: 1.1867547903876912e-08, Progress: 13.00%, approx. 1274.3 seconds remaining.
# Error: 1.1709512824588447e-08, Progress: 13.50%, approx. 1220.1 seconds remaining.
# Error: 1.1697519522004954e-08, Progress: 14.00%, approx. 1169.7 seconds remaining.
# Error: 1.1684983546876115e-08, Progress: 14.50%, approx. 1122.8 seconds remaining.
# Error: 1.1648270101557251e-08, Progress: 15.00%, approx. 1079.1 seconds remaining.
# Error: 9.552458106193033e-08, Progress: 15.50%, approx. 1379.2 seconds remaining.
# Error: 2.6181155339468363e-08, Progress: 16.00%, approx. 1328.2 seconds remaining.
# Error: 1.3531275154171086e-08, Progress: 16.50%, approx. 1280.3 seconds remaining.
# Error: 1.2893606047093235e-08, Progress: 17.00%, approx. 1235.2 seconds remaining.
# Error: 1.2290416648757339e-08, Progress: 17.50%, approx. 1192.7 seconds remaining.
# Error: 1.2216237216724921e-08, Progress: 18.00%, approx. 1152.5 seconds remaining.
# Error: 1.214497985836673e-08, Progress: 18.50%, approx. 1114.5 seconds remaining.
# Error: 1.2104953396620079e-08, Progress: 19.00%, approx. 1078.6 seconds remaining.
# Error: 1.206360704417686e-08, Progress: 19.50%, approx. 1044.4 seconds remaining.
# Error: 1.2067693406344324e-08, Progress: 20.00%, approx. 1012.0 seconds remaining.
# Error: 2.5881666165613818e-06, Progress: 20.50%, approx. 1096.0 seconds remaining.
# Error: 2.972996811059874e-07, Progress: 21.00%, approx. 1063.1 seconds remaining.
# Error: 1.2543393127245716e-08, Progress: 21.50%, approx. 1031.8 seconds remaining.
# Error: 1.1892528014580876e-08, Progress: 22.00%, approx. 1002.0 seconds remaining.
# Error: 1.1654185043230767e-08, Progress: 22.50%, approx. 973.4 seconds remaining.
# Error: 1.1651897764810499e-08, Progress: 23.00%, approx. 946.1 seconds remaining.
# Error: 1.1549270909118397e-08, Progress: 23.50%, approx. 920.0 seconds remaining.
# Error: 1.1507319578794308e-08, Progress: 24.00%, approx. 894.9 seconds remaining.
# Error: 1.1501070619019141e-08, Progress: 24.50%, approx. 870.9 seconds remaining.
# Error: 1.1485063991947864e-08, Progress: 25.00%, approx. 847.8 seconds remaining.
# Error: 1.1325523225964126e-06, Progress: 25.50%, approx. 917.4 seconds remaining.
# Error: 3.30959799012422e-08, Progress: 26.00%, approx. 893.7 seconds remaining.
# Error: 2.8284688519372805e-08, Progress: 26.50%, approx. 871.0 seconds remaining.
# Error: 2.9203476892587146e-08, Progress: 27.00%, approx. 849.0 seconds remaining.
# Error: 1.2067820549253316e-08, Progress: 27.50%, approx. 827.9 seconds remaining.
# Error: 1.2722250137071942e-08, Progress: 28.00%, approx. 807.5 seconds remaining.
# Error: 1.1746246460875765e-08, Progress: 28.50%, approx. 787.8 seconds remaining.
# Error: 1.188688506407432e-08, Progress: 29.00%, approx. 768.8 seconds remaining.
# Error: 1.1695898295902175e-08, Progress: 29.50%, approx. 750.5 seconds remaining.
# Error: 1.1541307688113027e-08, Progress: 30.00%, approx. 732.7 seconds remaining.
# Error: 2.5538598019640824e-07, Progress: 30.50%, approx. 779.5 seconds remaining.
# Error: 3.3023319356745756e-08, Progress: 31.00%, approx. 761.4 seconds remaining.
# Error: 2.4938473271079954e-08, Progress: 31.50%, approx. 743.9 seconds remaining.
# Error: 2.475535590832257e-08, Progress: 32.00%, approx. 726.9 seconds remaining.
# Error: 1.751856645873633e-08, Progress: 32.50%, approx. 710.5 seconds remaining.
# Error: 1.438477978745017e-08, Progress: 33.00%, approx. 694.5 seconds remaining.
# Error: 1.1873041299359914e-08, Progress: 33.50%, approx. 679.0 seconds remaining.
# Error: 1.1888882447464668e-08, Progress: 34.00%, approx. 664.0 seconds remaining.
# Error: 1.1752685225689242e-08, Progress: 34.50%, approx. 649.5 seconds remaining.
# Error: 1.174866729449972e-08, Progress: 35.00%, approx. 635.3 seconds remaining.
# Error: 1.8063406122615254e-07, Progress: 35.50%, approx. 675.2 seconds remaining.
# Error: 1.4831651410386396e-08, Progress: 36.00%, approx. 660.6 seconds remaining.
# Error: 1.3806094416875355e-08, Progress: 36.50%, approx. 646.5 seconds remaining.
# Error: 1.2863922966768339e-08, Progress: 37.00%, approx. 632.8 seconds remaining.
# Error: 1.247750815335935e-08, Progress: 37.50%, approx. 619.4 seconds remaining.
# Error: 1.2259995064215323e-08, Progress: 38.00%, approx. 606.3 seconds remaining.
# Error: 1.2132398111797531e-08, Progress: 38.50%, approx. 593.6 seconds remaining.
# Error: 1.178975630273698e-08, Progress: 39.00%, approx. 581.2 seconds remaining.
# Error: 1.182084131604047e-08, Progress: 39.50%, approx. 569.2 seconds remaining.
# Error: 1.1808526793560748e-08, Progress: 40.00%, approx. 557.4 seconds remaining.
# Error: 1.575931478802571e-07, Progress: 40.50%, approx. 581.7 seconds remaining.
# Error: 5.684580110981802e-07, Progress: 41.00%, approx. 569.8 seconds remaining.
# Error: 1.3303553197621451e-08, Progress: 41.50%, approx. 558.1 seconds remaining.
# Error: 1.3077928450795646e-08, Progress: 42.00%, approx. 546.8 seconds remaining.
# Error: 1.3954661689909172e-08, Progress: 42.50%, approx. 535.7 seconds remaining.
# Error: 1.1588606332230415e-08, Progress: 43.00%, approx. 524.9 seconds remaining.
# Error: 1.1520503135297702e-08, Progress: 43.50%, approx. 514.3 seconds remaining.
# Error: 1.1550769247153963e-08, Progress: 44.00%, approx. 503.9 seconds remaining.
# Error: 1.1569984707826065e-08, Progress: 44.50%, approx. 493.8 seconds remaining.
# Error: 1.1539820304180594e-08, Progress: 45.00%, approx. 483.9 seconds remaining.
# Error: 9.911602815879637e-08, Progress: 45.50%, approx. 504.5 seconds remaining.
# Error: 1.3470067045773236e-08, Progress: 46.00%, approx. 494.5 seconds remaining.
# Error: 1.2946304356056498e-08, Progress: 46.50%, approx. 484.6 seconds remaining.
# Error: 1.2845785512675596e-08, Progress: 47.00%, approx. 475.0 seconds remaining.
# Error: 1.2606929311443101e-08, Progress: 47.50%, approx. 465.6 seconds remaining.
# Error: 1.2319401627020953e-08, Progress: 48.00%, approx. 456.3 seconds remaining.
# Error: 1.2333665687419546e-08, Progress: 48.50%, approx. 447.3 seconds remaining.
# Error: 1.24001922748889e-08, Progress: 49.00%, approx. 438.4 seconds remaining.
# Error: 1.2364878006801762e-08, Progress: 49.50%, approx. 429.7 seconds remaining.
# Error: 1.234840801268526e-08, Progress: 50.00%, approx. 421.2 seconds remaining.
# Error: 1.327415651108374e-07, Progress: 50.50%, approx. 436.6 seconds remaining.
# Error: 5.7728052937183335e-08, Progress: 51.00%, approx. 427.9 seconds remaining.
# Error: 1.500237946510722e-08, Progress: 51.50%, approx. 419.5 seconds remaining.
# Error: 1.2204207218087745e-08, Progress: 52.00%, approx. 411.1 seconds remaining.
# Error: 1.1825332493542019e-08, Progress: 52.50%, approx. 403.0 seconds remaining.
# Error: 1.1956062638215274e-08, Progress: 53.00%, approx. 395.0 seconds remaining.
# Error: 1.198213367394604e-08, Progress: 53.50%, approx. 387.1 seconds remaining.
# Error: 1.191320515641829e-08, Progress: 54.00%, approx. 379.4 seconds remaining.
# Error: 1.1847167652260681e-08, Progress: 54.50%, approx. 371.9 seconds remaining.
# Error: 1.1778754039419997e-08, Progress: 55.00%, approx. 364.4 seconds remaining.
# Error: 2.0502632487839046e-06, Progress: 55.50%, approx. 376.4 seconds remaining.
# Error: 1.93356182368715e-07, Progress: 56.00%, approx. 368.9 seconds remaining.
# Error: 1.2945389754904252e-08, Progress: 56.50%, approx. 361.5 seconds remaining.
# Error: 1.23141848496593e-08, Progress: 57.00%, approx. 354.2 seconds remaining.
# Error: 1.1761106212558872e-08, Progress: 57.50%, approx. 347.0 seconds remaining.
# Error: 1.164675564756658e-08, Progress: 58.00%, approx. 340.0 seconds remaining.
# Error: 1.1602866217698878e-08, Progress: 58.50%, approx. 333.1 seconds remaining.
# Error: 1.159571477887735e-08, Progress: 59.00%, approx. 326.3 seconds remaining.
# Error: 1.1625940977071477e-08, Progress: 59.50%, approx. 319.6 seconds remaining.
# Error: 1.1622375700837567e-08, Progress: 60.00%, approx. 313.0 seconds remaining.
# Error: 1.1235570877827385e-07, Progress: 60.50%, approx. 322.3 seconds remaining.
# Error: 8.905227458946323e-08, Progress: 61.00%, approx. 315.6 seconds remaining.
# Error: 1.2687965365488858e-08, Progress: 61.50%, approx. 309.0 seconds remaining.
# Error: 1.2813981191750399e-08, Progress: 62.00%, approx. 302.5 seconds remaining.
# Error: 1.4164556517331559e-08, Progress: 62.50%, approx. 296.2 seconds remaining.
# Error: 1.1754392715588358e-08, Progress: 63.00%, approx. 289.9 seconds remaining.
# Error: 1.1519269192518964e-08, Progress: 63.50%, approx. 283.7 seconds remaining.
# Error: 1.1470907288667739e-08, Progress: 64.00%, approx. 277.6 seconds remaining.
# Error: 1.1501346349027577e-08, Progress: 64.50%, approx. 271.7 seconds remaining.
# Error: 1.1521692402258215e-08, Progress: 65.00%, approx. 265.8 seconds remaining.
# Error: 1.4058646542919626e-07, Progress: 65.50%, approx. 271.5 seconds remaining.
# Error: 1.9443470084723288e-08, Progress: 66.00%, approx. 265.5 seconds remaining.
# Error: 1.4369892037521948e-08, Progress: 66.50%, approx. 259.6 seconds remaining.
# Error: 1.3767021788195508e-08, Progress: 67.00%, approx. 253.9 seconds remaining.
# Error: 1.2335861848470963e-08, Progress: 67.50%, approx. 248.2 seconds remaining.
# Error: 1.2273305977653109e-08, Progress: 68.00%, approx. 242.6 seconds remaining.
# Error: 1.2266181727632363e-08, Progress: 68.50%, approx. 237.0 seconds remaining.
# Error: 1.2276185506557653e-08, Progress: 69.00%, approx. 231.6 seconds remaining.
# Error: 1.223900832210724e-08, Progress: 69.50%, approx. 226.2 seconds remaining.
# Error: 1.226980084776765e-08, Progress: 70.00%, approx. 220.9 seconds remaining.
# Error: 5.863892929064044e-08, Progress: 70.50%, approx. 224.4 seconds remaining.
# Error: 3.267477929327222e-08, Progress: 71.00%, approx. 219.0 seconds remaining.
# Error: 2.3713224982984158e-08, Progress: 71.50%, approx. 213.7 seconds remaining.
# Error: 1.2498542393396172e-08, Progress: 72.00%, approx. 208.5 seconds remaining.
# Error: 1.1537662705294443e-08, Progress: 72.50%, approx. 203.4 seconds remaining.
# Error: 1.1640544142384248e-08, Progress: 73.00%, approx. 198.3 seconds remaining.
# Error: 1.151228374953264e-08, Progress: 73.50%, approx. 193.3 seconds remaining.
# Error: 1.1368744146576413e-08, Progress: 74.00%, approx. 188.4 seconds remaining.
# Error: 1.1344454667773991e-08, Progress: 74.50%, approx. 183.5 seconds remaining.
# Error: 1.1350297855167881e-08, Progress: 75.00%, approx. 178.7 seconds remaining.
# Error: 1.2510629950431713e-07, Progress: 75.50%, approx. 180.6 seconds remaining.
# Error: 5.9502521949885845e-08, Progress: 76.00%, approx. 175.8 seconds remaining.
# Error: 1.860017285851048e-08, Progress: 76.50%, approx. 171.0 seconds remaining.
# Error: 1.209008465314029e-08, Progress: 77.00%, approx. 166.3 seconds remaining.
# Error: 1.2669808884533397e-08, Progress: 77.50%, approx. 161.6 seconds remaining.
# Error: 1.171602371660671e-08, Progress: 78.00%, approx. 157.0 seconds remaining.
# Error: 1.1573460321188628e-08, Progress: 78.50%, approx. 152.5 seconds remaining.
# Error: 1.153562974226723e-08, Progress: 79.00%, approx. 148.0 seconds remaining.
# Error: 1.1548345638909983e-08, Progress: 79.50%, approx. 143.5 seconds remaining.
# Error: 1.1562869164324296e-08, Progress: 80.00%, approx. 139.2 seconds remaining.
# Error: 4.0020852012929697e-07, Progress: 80.50%, approx. 139.8 seconds remaining.
# Error: 3.884534063826448e-08, Progress: 81.00%, approx. 135.4 seconds remaining.
# Error: 3.468832555120728e-08, Progress: 81.50%, approx. 131.0 seconds remaining.
# Error: 1.614669698032994e-08, Progress: 82.00%, approx. 126.7 seconds remaining.
# Error: 1.640703128375112e-08, Progress: 82.50%, approx. 122.4 seconds remaining.
# Error: 1.2738191785628082e-08, Progress: 83.00%, approx. 118.2 seconds remaining.
# Error: 1.214110695309467e-08, Progress: 83.50%, approx. 114.0 seconds remaining.
# Error: 1.2106707513720458e-08, Progress: 84.00%, approx. 109.9 seconds remaining.
# Error: 1.2032825968163181e-08, Progress: 84.50%, approx. 105.9 seconds remaining.
# Error: 1.2011378053291449e-08, Progress: 85.00%, approx. 101.9 seconds remaining.
# Error: 1.7904289250320954e-07, Progress: 85.50%, approx. 101.6 seconds remaining.
# Error: 1.3990303754980806e-07, Progress: 86.00%, approx. 97.5 seconds remaining.
# Error: 2.200846569917433e-08, Progress: 86.50%, approx. 93.5 seconds remaining.
# Error: 1.2247955946541104e-08, Progress: 87.00%, approx. 89.5 seconds remaining.
# Error: 1.1962077881937026e-08, Progress: 87.50%, approx. 85.6 seconds remaining.
# Error: 1.1612127204701724e-08, Progress: 88.00%, approx. 81.7 seconds remaining.
# Error: 1.1562473139015012e-08, Progress: 88.50%, approx. 77.8 seconds remaining.
# Error: 1.157844816187652e-08, Progress: 89.00%, approx. 74.0 seconds remaining.
# Error: 1.1559414514082648e-08, Progress: 89.50%, approx. 70.3 seconds remaining.
# Error: 1.1548420682610586e-08, Progress: 90.00%, approx. 66.6 seconds remaining.
# Error: 2.3333136019262427e-06, Progress: 90.50%, approx. 65.0 seconds remaining.
# Error: 4.526675026408176e-07, Progress: 91.00%, approx. 61.3 seconds remaining.
# Error: 6.528664500170468e-08, Progress: 91.50%, approx. 57.6 seconds remaining.
# Error: 1.241333718397603e-08, Progress: 92.00%, approx. 53.9 seconds remaining.
# Error: 1.2068022068486978e-08, Progress: 92.50%, approx. 50.2 seconds remaining.
# Error: 1.1722918349785126e-08, Progress: 93.00%, approx. 46.6 seconds remaining.
# Error: 1.1882798291056743e-08, Progress: 93.50%, approx. 43.1 seconds remaining.
# Error: 1.1804124505264764e-08, Progress: 94.00%, approx. 39.6 seconds remaining.
# Error: 1.18447322063475e-08, Progress: 94.50%, approx. 36.1 seconds remaining.
# Error: 1.1791524676466531e-08, Progress: 95.00%, approx. 32.6 seconds remaining.
# Error: 3.398132603257214e-06, Progress: 95.50%, approx. 30.1 seconds remaining.
# Error: 5.705514693128897e-08, Progress: 96.00%, approx. 26.6 seconds remaining.
# Error: 1.714231597021899e-08, Progress: 96.50%, approx. 23.2 seconds remaining.
# Error: 1.2151802541118988e-08, Progress: 97.00%, approx. 19.7 seconds remaining.
# Error: 1.2142324229567599e-08, Progress: 97.50%, approx. 16.4 seconds remaining.
# Error: 1.2113509962845637e-08, Progress: 98.00%, approx. 13.0 seconds remaining.
# Error: 1.2264241540698461e-08, Progress: 98.50%, approx. 9.7 seconds remaining.
# Error: 1.2085370433132184e-08, Progress: 99.00%, approx. 6.4 seconds remaining.
# Error: 1.1894582931991516e-08, Progress: 99.50%, approx. 3.2 seconds remaining.
# Error: 1.1866419443483321e-08, Progress: 100.00%, approx. 0.0 seconds remaining.

# %%
#Plot Error over training set sizes
plt.figure(figsize=(12, 8))  #Size
results_mean_cheby = np.mean(MSE_cheby, axis = 2)
results_lower_cheby = np.std(MSE_cheby, axis = 2)/results_mean_cheby # 90% confidence intervals

results_mean_leg = np.mean(MSE_leg, axis = 2)
results_lower_leg = np.std(MSE_leg, axis = 2)/results_mean_leg # 90% confidence intervals

results_mean = np.mean(MSE_slep, axis = 2)
results_lower = np.std(MSE_slep, axis = 2)/results_mean # 90% confidence intervals


for i in range(len(Para_slep)):
    plt.loglog(Nsamples, results_mean[i,:], label="Slepian basis")
    plt.fill_between(Nsamples, results_mean[i,:]/(1+results_lower[i,:]), results_mean[i,:]*(1+results_lower[i,:]),  alpha=0.2)

    plt.loglog(Nsamples, results_mean_cheby[i,:], label="Chebyschev")
    plt.fill_between(Nsamples, results_mean_cheby[i,:]/(1+results_lower_cheby[i,:]), results_mean_cheby[i,:]*(1+results_lower_cheby[i,:]),  alpha=0.2)

    plt.loglog(Nsamples, results_mean_leg[i,:], label="Legendre")
    plt.fill_between(Nsamples, results_mean_leg[i,:]/(1+results_lower_leg[i,:]), results_mean_leg[i,:]*(1+results_lower_leg[i,:]),  alpha=0.2)



plt.xlabel(r'$m$', fontsize=32, labelpad=18)
plt.ylabel(r'$\epsilon_{test}$', fontsize=32, labelpad=28)


# Increase font size of axis tick labels
plt.tick_params(axis='both', which='major', labelsize=28)  # Major ticks
plt.tick_params(axis='both', which='minor', labelsize=28)  # Minor ticks

plt.legend(fontsize=28, loc='lower left')

plt.legend(
    fontsize=24,
    loc='center left',
    bbox_to_anchor=(1.05, 0.5),  # Place the legend to the right of the plot
    ncol=1  # Single column for legend entries
)

plt.tight_layout()  # Asegura que todo se ajuste bien en la figura


plt.savefig("errorvsm_expo_uni.pdf")


plt.show()

# %%
results_mean_leg-results_mean_cheby
# Out:
# array([[ 2.64162222e-10,  7.65868133e-16, -2.40509394e-16,
#         -2.01212677e-18,  3.20439975e-17, -3.40127668e-17,
#         -1.49407612e-17, -6.99626450e-17,  3.43010227e-17,
#          5.75040080e-17]])

# %%
results_mean - results_mean_leg
# Out:
# array([[-1.77114464e-05, -2.91288183e-06, -5.77207452e-07,
#         -3.65887365e-07, -2.58500999e-07, -2.42520898e-07,
#         -2.37693939e-07, -2.36787394e-07, -2.36085304e-07,
#         -2.35639960e-07]])

# %%
results_mean - results_mean_cheby
# Out:
# array([[-1.77111822e-05, -2.91288182e-06, -5.77207452e-07,
#         -3.65887365e-07, -2.58500999e-07, -2.42520898e-07,
#         -2.37693939e-07, -2.36787394e-07, -2.36085304e-07,
#         -2.35639960e-07]])

# %%
print(test_PSWF_matrix.shape)
# Out:
# (1000, 10)

# %%
print(test_PSWF_matrix_.shape)
# Out:
# (1000, 10)
